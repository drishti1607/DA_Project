# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\Users\\shubh'

# %%
# %cd E:\DA_Project\Crime
# Out:
# E:\DA_Project\Crime

# %%
dataset = pd.read_csv('42_Cases_under_crime_against_women.csv')

# %%
list2 = ['Karnataka','Maharashtra','Uttar Pradesh']
rural2 =dataset.loc[dataset['Area_Name'].isin(list2)]

# %%
import seaborn as sns 
corrmat = rural2.corr() 
  
f, ax = plt.subplots(figsize =(9, 9)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)
